# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import cv2
import random
import matplotlib
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D,Activation,MaxPooling2D,Dense,Flatten,Dropout
from tensorflow.keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow import keras


from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, GlobalAveragePooling2D, Dense, Dropout
from keras.layers.merge import concatenate

from keras.datasets import cifar10
import string
import csv

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Fri May  6 00:17:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8    29W / 149W |      3MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Num GPUs Available:  1

# %% [markdown]
# ## Acquiring Dataset

# %%
# import sys
# prefix = '/content/gdrive/SharedDrives/'
# # modify "customized_path_to_your_homework" here to where you uploaded your homework
# customized_path_to_your_homework = 'AML_Project/GTSRB_Final_Training_Images/GTSRB/Final_Training/Images/'
# sys_path = prefix + customized_path_to_your_homework
# sys.path.append(sys_path)

# %%
# path_files = prefix + "AML_Project/"
# sys.path.append(path_files)

# %%
# loaded_ytr = np.loadtxt('/content/gdrive/Shareddrives/AML_Project/y_train_final.txt')
# trainy = loaded_ytr.reshape(loaded_ytr.shape[0], 43)

# %%
# loaded_xtr = np.loadtxt('/content/gdrive/Shareddrives/AML_Project/X_train_final.txt')
# trainX = loaded_xtr.reshape(loaded_xtr.shape[0], 32,32,3)

# %%
# loaded_yte = np.loadtxt('/content/gdrive/Shareddrives/AML_Project/y_test_final.txt')
# testy = loaded_yte.reshape(loaded_yte.shape[0], 43)

# %%
# loaded_xte = np.loadtxt('/content/gdrive/Shareddrives/AML_Project/X_test_final.txt')
# testX = loaded_xte.reshape(loaded_xte.shape[0], 32,32,3)

# %%
# X_train = trainX
# y_train = trainy
# X_test = testX
# y_test = testy

# %%
# print(X_train.shape)
# print(y_train.shape)
# print(X_test.shape)
# print(y_test.shape)

# %% [markdown]
# ## Kaggle

# %%
# %%capture
# !pip install kaggle

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-f37b3e0b-51a9-49ce-87c5-114c499b65a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f37b3e0b-51a9-49ce-87c5-114c499b65a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 65 bytes

# %%
# !kaggle datasets list -s ['gtsrb']
# Out:
# ref                                                                         title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign                     GTSRB - German Traffic Sign Recognition Benchmark  612MB  2018-11-25 18:12:34          54778        807  0.8235294
# datasets/eunjurho/german-traffic-sign-recognition-benchmark-cropped         german_traffic_sign_recognition_benchmark_cropped  206MB  2019-11-10 15:22:13            269          7  0.75
# datasets/shanmukh05/traffic-sign-cropped                                    Traffic Sign Recognition Cropped Images             43MB  2021-03-05 11:49:40            460         18  0.88235295
# datasets/valentynsichkar/traffic-signs-preprocessed                         Traffic Signs Preprocessed                           4GB  2019-08-31 18:22:11           7838        221  1.0
# datasets/daniildeltsov/traffic-signs-gtsrb-plus-162-custom-classes          Traffic Signs (GTSRB plus 162 custom classes)       15GB  2022-04-15 14:59:47             46         12  0.8235294
# datasets/namgalielei/gtsrb-autocar-club                                     GTSRB [Autocar Club]                               702MB  2019-05-27 16:25:15             20          3  0.11764706
# datasets/ganeshishwarpatil/gtsrblabel-names                                 gtsrb-label_names                                   651B  2021-08-27 14:25:59             17          1  0.1764706
# datasets/eiriksteira/gtsrb-models-idatt-2502                                gtsrb-models-idatt-2502                            541MB  2021-11-28 10:27:01              9          1  0.23529412
# datasets/bhavinmoriya/german-traffic-sign-recognition-benchmark             German Traffic Sign Recognition Benchmark          306MB  2021-12-17 17:03:58             13          3  0.3529412
# datasets/hariharans18itr033/gtsrb-dataset                                   GTSRB dataset                                      233MB  2022-03-20 16:32:22              3          0  0.25
# datasets/bakerholms/gtsrbsmall                                              gtsrb-small                                          9MB  2021-05-31 19:01:10              2          0  0.125
# datasets/sqimeng/gtsrbgreyscale2k                                           GTSRB-greyscale-2k                                 110MB  2020-11-11 08:58:30             35          0  0.25
# datasets/valentynsichkar/traffic-signs-1-million-images-for-classification  Traffic Signs 1 million images for Classification   20GB  2021-02-08 16:45:43            210          5  1.0
# datasets/valentynsichkar/preprocessed-light-version-of-traffic-signs        Pre-processed Light version of Traffic Signs         8GB  2021-04-10 13:35:24             34          2  1.0
# datasets/sqimeng/gtsrbtestgreyscale500                                      GTSRB-test-greyscale-500                            26MB  2020-11-13 07:57:53              8          0  0.125
# datasets/jorisonkaggle/gtsrb-final-training-dataset                         GTSRB final training dataset                       265MB  2021-03-06 10:07:56              9          0  0.125
# datasets/agnetazhintia1024/gtsrb-kagglecsv                                  gtsrb_kaggle.csv                                    42KB  2020-10-20 22:17:46              5          0  0.23529412
# datasets/adamxt/gtsrb-data                                                  GTSRB_data                                         349MB  2021-07-05 13:10:16              3          0  0.125
# datasets/amitkumarjaiswal/gtsrbd                                            gtsrbd                                             349MB  2020-05-23 20:48:38              1          0  0.11764706
# datasets/definite93/gtsrbdata                                               gtsrbdata                                          349MB  2020-07-01 17:54:39              4          0  0.11764706

# %%
# !kaggle datasets download -d meowmeowmeowmeowmeow/gtsrb-german-traffic-sign
# Out:
# Downloading gtsrb-german-traffic-sign.zip to /content
#  98% 599M/612M [00:04<00:00, 141MB/s]
# 100% 612M/612M [00:04<00:00, 133MB/s]

# %%
# %%capture
# !unzip gtsrb-german-traffic-sign.zip

# %%
# Labels Overview
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
data_dir = '/content/'
train_path = '/content/Train'
test_path = '/content/Test'

# %%
n = pd.read_csv(data_dir + '/Train.csv')
n_classes = len(set(n['ClassId'].values))
print(f"Number of classes: {n_classes}")
# Out:
# Number of classes: 43

# %% [markdown]
# ## Visualizing Dataset

# %%
folders = os.listdir(train_path)

train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])
    
# Sorting the dataset on the basis of number of images in each class
zipped_lists = zip(train_number, class_num)
sorted_pairs = sorted(zipped_lists)
tuples = zip(*sorted_pairs)
train_number, class_num = [ list(tuple) for tuple in  tuples]

# Plotting the number of images in each class
plt.figure(figsize=(15,7))  
plt.bar(class_num, train_number)
plt.xticks(class_num, rotation='vertical')
plt.title("Number of Images in each class")
plt.show()

# %%
# Visualizing 25 random images from test data
import random
from matplotlib.image import imread

test = pd.read_csv(data_dir + '/Test.csv')
imgs = test["Path"].values
ids = test["ClassId"].values
mat = np.column_stack((ids,imgs))

plt.figure(figsize=(21,21))
plt.subplots_adjust(hspace=.5)

for i in range(1,26):
    plt.subplot(5,5,i)
    random_img_path_id = random.choice(mat)
    rand_img = imread(data_dir + '/' + random_img_path_id[1])
    rand_id = random_img_path_id[0]
    plt.imshow(rand_img)
    plt.xlabel(f"Width of image: {rand_img.shape[1]}")     #width of image
    plt.ylabel(f"Height of image: {rand_img.shape[0]}")    #height of image
    plt.title(f"Class: {classes.get(rand_id)}")

# %% [markdown]
# ## Creating Dataset

# %%
data = []
labels = []

for i in range(n_classes):
    path = data_dir + '/Train/' + str(i)
    images = os.listdir(path)

    for img in images:
      image = cv2.imread(path + '/' + img)
      rz = cv2.resize(image, (32,32), interpolation = cv2.INTER_NEAREST)
      data.append(np.array(rz))
      labels.append(i)

data = np.array(data)
labels = np.array(labels)
print(f"data shape: {data.shape}")
print(f"labels shape: {labels.shape}")
# Out:
# data shape: (39209, 32, 32, 3)
# labels shape: (39209,)

# %%
#Random Image from data set
print(data[300].shape)
img = cv2.cvtColor(data[300], cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
print(labels[300])
# Out:
# (32, 32, 3)
# 1

# %%
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, random_state=41, shuffle=True)

X_train = X_train/255     # Normalizing Values
X_val = X_val/255         # Normalizing Values
print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (31367, 32, 32, 3)
# X_valid.shape (7842, 32, 32, 3)
# y_train.shape (31367,)
# y_valid.shape (7842,)

# %%
y_train = keras.utils.to_categorical(y_train, n_classes)
y_val = keras.utils.to_categorical(y_val, n_classes)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# y_train.shape (31367, 43)
# y_valid.shape (7842, 43)

# %% [markdown]
# ## Model Architecture

# %%
def Inception_block(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4): 
  # Input: 
  # - f1: number of filters of the 1x1 convolutional layer in the first path
  # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
  # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
  # - f4: number of filters of the 1x1 convolutional layer in the fourth path

  # 1st path:
  path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)

  # 2nd path
  path2 = Conv2D(filters = f2_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path2 = Conv2D(filters = f2_conv3, kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  # 3rd path
  path3 = Conv2D(filters = f3_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path3 = Conv2D(filters = f3_conv5, kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input_layer)
  path4 = Conv2D(filters = f4, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer

# %%
def GoogLeNet(X):
  # input layer 
  input_layer = Input(shape = (X.shape[1], X.shape[2], X.shape[3]))

  # convolutional layer: filters = 64, kernel_size = (7,7), strides = 2
  X = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

  # max-pooling layer: pool_size = (3,3), strides = 2
  #X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  #X = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  #X = Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  #X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 1st Inception block
  X = Inception_block(X, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

  # 2nd Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2, padding='same')(X)

  # 3rd Inception block
  X = Inception_block(X, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)
  
  # 4th Inception block
  X = Inception_block(X, f1 = 160, f2_conv1 = 112, f2_conv3 = 224, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 5th Inception block
  #X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 256, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 6th Inception block
  #X = Inception_block(X, f1 = 112, f2_conv1 = 144, f2_conv3 = 288, f3_conv1 = 32, f3_conv5 = 64, f4 = 64)
  
  # 7th Inception block
  #X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2, padding='same')(X)

  # 8th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

  # 9th Inception block
  X = Inception_block(X, f1 = 384, f2_conv1 = 192, f2_conv3 = 384, f3_conv1 = 48, f3_conv5 = 128, f4 = 128)

  # Global Average pooling layer 
  X = GlobalAveragePooling2D()(X)

  # Dropoutlayer 
  X = Dropout(0.4)(X)

  # output layer 
  X = Dense(43, activation = 'softmax')(X)
  
  # model
  model = Model(input_layer, X, name = 'GoogLeNet')

  return model

model_google = GoogLeNet(X_train)
model_google.summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 15, 15, 64)   1792        ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 15, 15, 96)   6240        ['conv2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 15, 15, 16)   1040        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 15, 15, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 15, 15, 64)   4160        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 15, 15, 128)  110720      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 15, 15, 32)   12832       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 15, 15, 32)   2080        ['max_pooling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 15, 15, 256)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 15, 15, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 15, 15, 32)   8224        ['concatenate[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 15, 15, 256)  0          ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 15, 15, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 15, 15, 192)  221376      ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 15, 15, 96)   76896       ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 15, 15, 64)   16448       ['max_pooling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 15, 15, 480)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 480)   0           ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 96)     46176       ['max_pooling2d_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 8, 8, 16)     7696        ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 480)   0           ['max_pooling2d_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 192)    92352       ['max_pooling2d_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 208)    179920      ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 8, 8, 48)     19248       ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 8, 8, 64)     30784       ['max_pooling2d_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 512)    0           ['conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 112)    57456       ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 24)     12312       ['concatenate_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 512)   0           ['concatenate_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 160)    82080       ['concatenate_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 224)    226016      ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 64)     38464       ['conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 64)     32832       ['max_pooling2d_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 8, 8, 512)    0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 512)   0           ['concatenate_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 4, 4, 160)    82080       ['max_pooling2d_5[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 4, 4, 32)     16416       ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 512)   0           ['max_pooling2d_5[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 4, 256)    131328      ['max_pooling2d_5[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 4, 4, 320)    461120      ['conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 4, 4, 128)    102528      ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 128)    65664       ['max_pooling2d_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 4, 4, 832)    0           ['conv2d_25[0][0]',
#                                                                   'conv2d_27[0][0]',
#                                                                   'conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 192)    159936      ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 4, 4, 48)     39984       ['concatenate_4[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 4, 4, 832)   0           ['concatenate_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 4, 4, 384)    319872      ['concatenate_4[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 4, 4, 384)    663936      ['conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 4, 4, 128)    153728      ['conv2d_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 4, 4, 128)    106624      ['max_pooling2d_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 4, 4, 1024)   0           ['conv2d_31[0][0]',
#                                                                   'conv2d_33[0][0]',
#                                                                   'conv2d_35[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['concatenate_5[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1024)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 43)           44075       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 3,700,227
# Trainable params: 3,700,227
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Visualizing Model

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 5.3 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
import visualkeras
visualkeras.layered_view(model_google, legend=True, spacing=20)
# Out:
# <PIL.Image.Image image mode=RGBA size=2908x207 at 0x7F1F8B8B0510>

# %% [markdown]
# ## Training

# %%
# Parameters
bs = 128
ep = 50
lr = 0.0001

opt = Adam(learning_rate=lr)
model_google.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Augmenting Training Data
data_gen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode="nearest")

history_google = model_google.fit(data_gen.flow(X_train, y_train, batch_size=bs), epochs=ep, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 246/246 [==============================] - 69s 197ms/step - loss: 3.2729 - accuracy: 0.1096 - val_loss: 2.7295 - val_accuracy: 0.2216
# Epoch 2/50
# 246/246 [==============================] - 47s 189ms/step - loss: 2.4323 - accuracy: 0.2815 - val_loss: 1.8220 - val_accuracy: 0.4199
# Epoch 3/50
# 246/246 [==============================] - 46s 186ms/step - loss: 1.7416 - accuracy: 0.4416 - val_loss: 1.4260 - val_accuracy: 0.5303
# Epoch 4/50
# 246/246 [==============================] - 47s 189ms/step - loss: 1.3504 - accuracy: 0.5470 - val_loss: 0.9687 - val_accuracy: 0.6820
# Epoch 5/50
# 246/246 [==============================] - 47s 192ms/step - loss: 1.0372 - accuracy: 0.6450 - val_loss: 0.7240 - val_accuracy: 0.7568
# Epoch 6/50
# 246/246 [==============================] - 52s 211ms/step - loss: 0.7714 - accuracy: 0.7416 - val_loss: 0.4588 - val_accuracy: 0.8504
# Epoch 7/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.5820 - accuracy: 0.8056 - val_loss: 0.4133 - val_accuracy: 0.8695
# Epoch 8/50
# 246/246 [==============================] - 47s 191ms/step - loss: 0.4434 - accuracy: 0.8545 - val_loss: 0.2547 - val_accuracy: 0.9245
# Epoch 9/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.3391 - accuracy: 0.8899 - val_loss: 0.1721 - val_accuracy: 0.9496
# Epoch 10/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.2730 - accuracy: 0.9126 - val_loss: 0.1474 - val_accuracy: 0.9538
# Epoch 11/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.2171 - accuracy: 0.9310 - val_loss: 0.1213 - val_accuracy: 0.9663
# Epoch 12/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.1913 - accuracy: 0.9385 - val_loss: 0.0912 - val_accuracy: 0.9714
# Epoch 13/50
# 246/246 [==============================] - 46s 189ms/step - loss: 0.1717 - accuracy: 0.9445 - val_loss: 0.0773 - val_accuracy: 0.9756
# Epoch 14/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.1436 - accuracy: 0.9549 - val_loss: 0.0663 - val_accuracy: 0.9799
# Epoch 15/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.1240 - accuracy: 0.9605 - val_loss: 0.0605 - val_accuracy: 0.9807
# Epoch 16/50
# 246/246 [==============================] - 47s 189ms/step - loss: 0.1112 - accuracy: 0.9644 - val_loss: 0.3047 - val_accuracy: 0.9008
# Epoch 17/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.1059 - accuracy: 0.9663 - val_loss: 0.0573 - val_accuracy: 0.9832
# Epoch 18/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.1003 - accuracy: 0.9697 - val_loss: 0.0653 - val_accuracy: 0.9790
# Epoch 19/50
# 246/246 [==============================] - 47s 189ms/step - loss: 0.0799 - accuracy: 0.9750 - val_loss: 0.0649 - val_accuracy: 0.9791
# Epoch 20/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0666 - accuracy: 0.9796 - val_loss: 0.0420 - val_accuracy: 0.9869
# Epoch 21/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0707 - accuracy: 0.9774 - val_loss: 0.0438 - val_accuracy: 0.9898
# Epoch 22/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.0642 - accuracy: 0.9797 - val_loss: 0.0326 - val_accuracy: 0.9902
# Epoch 23/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0524 - accuracy: 0.9841 - val_loss: 0.0264 - val_accuracy: 0.9922
# Epoch 24/50
# 246/246 [==============================] - 46s 189ms/step - loss: 0.0456 - accuracy: 0.9853 - val_loss: 0.0285 - val_accuracy: 0.9904
# Epoch 25/50
# 246/246 [==============================] - 46s 189ms/step - loss: 0.0557 - accuracy: 0.9827 - val_loss: 0.0239 - val_accuracy: 0.9913
# Epoch 26/50
# 246/246 [==============================] - 46s 186ms/step - loss: 0.0443 - accuracy: 0.9860 - val_loss: 0.0234 - val_accuracy: 0.9920
# Epoch 27/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0423 - accuracy: 0.9863 - val_loss: 0.0195 - val_accuracy: 0.9941
# Epoch 28/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.0462 - accuracy: 0.9850 - val_loss: 0.0347 - val_accuracy: 0.9892
# Epoch 29/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0352 - accuracy: 0.9885 - val_loss: 0.0225 - val_accuracy: 0.9926
# Epoch 30/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0408 - accuracy: 0.9877 - val_loss: 0.0200 - val_accuracy: 0.9944
# Epoch 31/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0412 - accuracy: 0.9881 - val_loss: 0.0196 - val_accuracy: 0.9941
# Epoch 32/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 0.0201 - val_accuracy: 0.9927
# Epoch 33/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0333 - accuracy: 0.9894 - val_loss: 0.0259 - val_accuracy: 0.9912
# Epoch 34/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.0193 - val_accuracy: 0.9935
# Epoch 35/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.0201 - val_accuracy: 0.9938
# Epoch 36/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.0191 - val_accuracy: 0.9945
# Epoch 37/50
# 246/246 [==============================] - 46s 189ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.0136 - val_accuracy: 0.9964
# Epoch 38/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.0119 - val_accuracy: 0.9964
# Epoch 39/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0250 - accuracy: 0.9922 - val_loss: 0.0210 - val_accuracy: 0.9923
# Epoch 40/50
# 246/246 [==============================] - 46s 189ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0080 - val_accuracy: 0.9976
# Epoch 41/50
# 246/246 [==============================] - 47s 191ms/step - loss: 0.0195 - accuracy: 0.9941 - val_loss: 0.0198 - val_accuracy: 0.9941
# Epoch 42/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 43/50
# 246/246 [==============================] - 46s 187ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.0136 - val_accuracy: 0.9953
# Epoch 44/50
# 246/246 [==============================] - 47s 190ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.0166 - val_accuracy: 0.9935
# Epoch 45/50
# 246/246 [==============================] - 47s 193ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0133 - val_accuracy: 0.9960
# Epoch 46/50
# 246/246 [==============================] - 46s 188ms/step - loss: 0.0301 - accuracy: 0.9904 - val_loss: 0.0095 - val_accuracy: 0.9977
# Epoch 47/50
# 246/246 [==============================] - 47s 192ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.0098 - val_accuracy: 0.9974
# Epoch 48/50
# 246/246 [==============================] - 52s 209ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0084 - val_accuracy: 0.9963
# Epoch 49/50
# 246/246 [==============================] - 47s 189ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0058 - val_accuracy: 0.9980
# Epoch 50/50
# 246/246 [==============================] - 47s 189ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0045 - val_accuracy: 0.9987

# %%
model_google.save('/content/gdrive/Shareddrives/AML_Project/google.h5')

# %%
model_google.save('/content/gdrive/Shareddrives/AML_Project/google_final')
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/Shareddrives/AML_Project/google_final/assets

# %%
reconstructed_model = keras.models.load_model("/content/gdrive/Shareddrives/AML_Project/google_final/")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-34eea0dd9355> in <module>()
# ----> 1 history_google = model_google.fit(data_gen.flow(X_train, y_train, batch_size=bs), epochs=ep, validation_data=(X_val, y_val))
#
# NameError: name 'data_gen' is not defined

# %% [markdown]
# ## Evaluating Model

# %%
plt.figure(figsize=(15,7))
plt.plot(history_google.history['accuracy'])
plt.plot(history_google.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training accuracy', 'validation accuracy'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(history_google.history['loss'])
plt.plot(history_google.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training loss', 'validation loss'], loc='upper left')
plt.show()

# %%
test = pd.read_csv(data_dir + '/Test.csv')

test_labels = test["ClassId"].values
test_imgs = test["Path"].values
print(len(test_imgs))
test_data =[]

for img in test_imgs:
  image = cv2.imread(data_dir+'/'+img)
  rz = cv2.resize(image, (32, 32), interpolation = cv2.INTER_NEAREST)
  test_data.append(rz)

X_test = np.array(test_data)
X_test = X_test/255         # Normalizing Values

print("X_test.shape", X_test.shape)
# Out:
# 12630
# X_test.shape (12630, 32, 32, 3)

# %%
from sklearn.metrics import accuracy_score
pred = model_google.predict(X_test)
pred_classes=np.argmax(pred, axis=1)

#Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(test_labels, pred_classes)*100)
# Out:
# Test Data accuracy:  96.24703087885986

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       0.95      0.99      0.97       720
#            2       0.97      0.99      0.98       750
#            3       0.98      0.96      0.97       450
#            4       1.00      0.93      0.96       660
#            5       0.96      0.98      0.97       630
#            6       0.99      0.98      0.99       150
#            7       1.00      0.94      0.97       450
#            8       0.95      1.00      0.97       450
#            9       0.99      1.00      1.00       480
#           10       1.00      1.00      1.00       660
#           11       0.96      0.91      0.93       420
#           12       0.99      0.93      0.96       690
#           13       0.93      1.00      0.97       720
#           14       1.00      1.00      1.00       270
#           15       0.98      0.99      0.98       210
#           16       1.00      1.00      1.00       150
#           17       1.00      0.92      0.96       360
#           18       0.99      0.85      0.91       390
#           19       1.00      0.80      0.89        60
#           20       0.80      1.00      0.89        90
#           21       0.76      0.78      0.77        90
#           22       0.98      0.77      0.86       120
#           23       0.85      1.00      0.92       150
#           24       0.91      0.99      0.95        90
#           25       0.94      0.97      0.95       480
#           26       0.98      0.99      0.98       180
#           27       0.62      0.67      0.64        60
#           28       0.92      0.95      0.93       150
#           29       0.87      1.00      0.93        90
#           30       0.78      0.84      0.81       150
#           31       0.99      1.00      0.99       270
#           32       1.00      1.00      1.00        60
#           33       0.98      0.99      0.99       210
#           34       0.97      1.00      0.98       120
#           35       0.99      0.97      0.98       390
#           36       0.98      0.99      0.99       120
#           37       1.00      1.00      1.00        60
#           38       1.00      0.96      0.98       690
#           39       1.00      0.97      0.98        90
#           40       0.80      0.98      0.88        90
#           41       0.97      0.98      0.98        60
#           42       0.88      0.98      0.93        90
#
#     accuracy                           0.96     12630
#    macro avg       0.94      0.95      0.95     12630
# weighted avg       0.96      0.96      0.96     12630

# %% [markdown]
# ## Predicting

# %%
plt.figure(figsize = (25, 25))

start_idx = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = pred_classes[start_idx + i + 100]
    actual = test_labels[start_idx + i + 100]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.imshow(cv2.cvtColor(np.array(X_test[start_idx + i + 100], dtype=np.float32), cv2.COLOR_BGR2RGB))
    plt.xlabel(f'Actual: {classes.get(actual)}''\n'f'Pred: {classes.get(prediction)}', color = col)
plt.show()
